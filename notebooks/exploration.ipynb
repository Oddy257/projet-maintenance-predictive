# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Charger le fichier Excel
df = pd.read_excel('../data/raw/predictive_maintenance_clean2.xlsx')

# Afficher les premières lignes
df.head()
